# %%
diemToan=float(input("Nhập điểm Toán:"))
diemVan=float(input("Nhập điểm Văn:"))
diemTin=float(input("Nhập điểm Tin:"))
dtb=(diemToan*2+diemVan*2+diemTin*1) / 5
print("Điểm trung bình là:"+str(dtb))
# Out:
# Điểm trung bình là:8.0

# %%
x = float(input( "Nhap x ="))
y = float(input("Nhap y = "))
tong = x + y
hieu = x - y
tich = x * y
thuong = x / y
print("Tong" + str(tong))
print("Hieu "+ str(hieu))
print("Tich "+ str(tich))
print("Thuong "+ str(thuong))
# Out:
# Tong13.0
# Hieu -3.0
# Tich 40.0
# Thuong 0.625

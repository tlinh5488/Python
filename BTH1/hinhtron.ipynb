# %%
import math
r=float(input("Nhập bán kính:"))
chuVi = 2*r*math.pi
dienTich=r*r*math.pi
print("Chu vi hình tròn là:"+str(chuVi))
print("Diện tích hình tròn là:"+str(dienTich))
# Out:
# Chu vi hình tròn là:15.707963267948966
# Diện tích hình tròn là:19.634954084936208

# %%
mon=input("Nhập môn học:")
diem=float(input("Nhập điểm môn "+mon+" :"))
if diem<4:
    he4=1.0
    hechu="F"
elif diem<5:
    he4=1.5
    hechu="D"
elif diem<6:
    he4=2
    hechu="C"
elif diem<7:
    he4=2.5
    hechu="B"
elif diem<8:
    he4=3.0
    hechu="B+"
elif diem<9:
    he4=3.5
    hechu="A"
else:
    he4=4.0
    hechu="A+"
print("Điểm " + mon + " Thang điểm 10:"+str(diem)+" Thang điểm 4:"+str(he4)+" Thang điểm chữ :"+str(hechu))
# Out:
# Điểm Python Thang điểm 10:8.5 Thang điểm 4:3.5 Thang điểm chữ :A

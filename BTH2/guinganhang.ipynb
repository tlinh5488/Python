# %%
tienCo=float(input("Nhập số tiền nhận:"))
thang=float(input("Nhập số tháng gửi:"))
lai=float(input("Nhập lãi suất trong 1 tháng:"))
tienGui = tienCo / ((1+lai)** thang)
print("Số tiền ít nhất phải gửi là:", tienGui)
# Out:
# Số tiền ít nhất phải gửi là: 1162840.1968068895

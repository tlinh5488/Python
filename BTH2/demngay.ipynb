# %%
thang=int(input("Nhập tháng:"))
nam=int(input("Nhập năm:"))
if thang in (1,3,5,7,8,10,12):
    soNgay = 31
elif thang in (4,6,9,11):
    soNgay = 30
elif thang == 2:
    if nam%400:
        soNgay = 29
    else:
        soNgay = 28
else:
    soNgay = 0
print("Tháng "+ str(thang)+" có " +str(soNgay)+" ngày")
# Out:
# Tháng 12 có 31 ngày
